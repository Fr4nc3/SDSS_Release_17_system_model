# %% [markdown]
# # 3. Experimental Approach
# # I. Data Collection and Preprocessing

# %%
import pandas as pd
file_path = 'photometric_stars.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#           objID  skyVersion  run  rerun  camcol  field  obj  mode  nChild  \
# 0  1.237650e+18           2  756    301       2    429  182     1       0
# 1  1.237650e+18           2  756    301       2    429  184     1       0
# 2  1.237650e+18           2  756    301       2    429  218     1       0
# 3  1.237650e+18           2  756    301       2    430   54     1       0
# 4  1.237650e+18           2  756    301       2    430   56     1       0
#
#    type  ...  nMgyPerCount_u  nMgyPerCount_g  nMgyPerCount_r  nMgyPerCount_i  \
# 0     6  ...        0.007356        0.003533        0.004715        0.007707
# 1     6  ...        0.007356        0.003532        0.004714        0.007708
# 2     6  ...        0.007389        0.003540        0.004734        0.007705
# 3     6  ...        0.007355        0.003546        0.004748        0.007702
# 4     6  ...        0.007324        0.003534        0.004721        0.007720
#
#    nMgyPerCount_z       TAI_u       TAI_g       TAI_r       TAI_i       TAI_z
# 0        0.032142  4428803189  4428803333  4428803046  4428803117  4428803261
# 1        0.032142  4428803189  4428803333  4428803046  4428803117  4428803261
# 2        0.032192  4428803197  4428803340  4428803053  4428803125  4428803268
# 3        0.032180  4428803242  4428803386  4428803099  4428803171  4428803314
# 4        0.032182  4428803245  4428803389  4428803102  4428803174  4428803317
#
# [5 rows x 509 columns]

# %%
data.describe(include='all')
# Out:
#               objID  skyVersion         run   rerun       camcol        field  \
# count  5.000000e+03      5000.0  5000.00000  5000.0  5000.000000  5000.000000
# mean   1.237656e+18         2.0  2615.39600   301.0     3.183400   339.808400
# std    9.234254e+12         0.0  2787.35969     0.0     0.606826   138.128449
# min    1.237650e+18         2.0   756.00000   301.0     2.000000   130.000000
# 25%    1.237650e+18         2.0   756.00000   301.0     3.000000   135.000000
# 50%    1.237650e+18         2.0   756.00000   301.0     3.000000   430.000000
# 75%    1.237670e+18         2.0  6793.00000   301.0     4.000000   433.000000
# max    1.237670e+18         2.0  6793.00000   301.0     4.000000   435.000000
#
#                obj    mode  nChild    type  ...  nMgyPerCount_u  \
# count  5000.000000  5000.0  5000.0  5000.0  ...     5000.000000
# mean    541.762600     1.0     0.0     6.0  ...        0.008640
# std     343.426336     0.0     0.0     0.0  ...        0.002167
# min       2.000000     1.0     0.0     6.0  ...        0.007033
# 25%     232.000000     1.0     0.0     6.0  ...        0.007141
# 50%     522.000000     1.0     0.0     6.0  ...        0.007263
# 75%     833.250000     1.0     0.0     6.0  ...        0.011797
# max    1309.000000     1.0     0.0     6.0  ...        0.013188
#
#        nMgyPerCount_g  nMgyPerCount_r  nMgyPerCount_i  nMgyPerCount_z  \
# count     5000.000000     5000.000000     5000.000000     5000.000000
# mean         0.003635        0.004825        0.006552        0.036512
# std          0.000287        0.000329        0.000498        0.001801
# min          0.003412        0.004457        0.006121        0.032034
# 25%          0.003428        0.004503        0.006152        0.035984
# 50%          0.003435        0.004719        0.006248        0.036754
# 75%          0.004055        0.005280        0.006821        0.038212
# max          0.004094        0.005661        0.007735        0.039462
#
#               TAI_u         TAI_g         TAI_r         TAI_i         TAI_z
# count  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03
# mean   4.507333e+09  4.507333e+09  4.507332e+09  4.507332e+09  4.507333e+09
# std    1.177206e+08  1.177206e+08  1.177206e+08  1.177206e+08  1.177206e+08
# min    4.428803e+09  4.428803e+09  4.428803e+09  4.428803e+09  4.428803e+09
# 25%    4.428803e+09  4.428803e+09  4.428803e+09  4.428803e+09  4.428803e+09
# 50%    4.428803e+09  4.428804e+09  4.428803e+09  4.428803e+09  4.428803e+09
# 75%    4.683768e+09  4.683768e+09  4.683768e+09  4.683768e+09  4.683768e+09
# max    4.683768e+09  4.683769e+09  4.683768e+09  4.683768e+09  4.683769e+09
#
# [8 rows x 509 columns]

# %%
data[['ra', 'dec', 'u', 'g', 'r', 'i', 'z']].describe()
# Out:
#                 ra          dec            u            g            r  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean    180.494965    -0.085177    23.084954    21.851785    20.862216
# std       0.290206     0.283467     1.925278     2.126992     1.947216
# min     180.000500    -0.499868    15.007210    14.436510    14.053450
# 25%     180.242429    -0.316801    22.273715    20.757568    19.894832
# 50%     180.491695    -0.150236    23.551495    22.404110    21.442600
# 75%     180.751015     0.236745    24.404998    23.369678    22.347720
# max     180.999968     0.420112    26.618570    26.234590    25.531270
#
#                  i            z
# count  5000.000000  5000.000000
# mean     20.397428    20.061306
# std       2.030809     2.024569
# min      13.716490    12.778910
# 25%      19.291635    18.886545
# 50%      20.814335    20.462295
# 75%      21.874643    21.616622
# max      25.207790    24.142400

# %%
problematic_flags = ['EDGE', 'NOPROFILE', 'SATURATED', 'COSMIC_RAY', 'INTERP_CENTER']

available_flags = [flag for flag in problematic_flags if flag in data.columns]

filtered_data = data.copy()
for flag in available_flags:
    if flag == 'INTERP_CENTER' and 'COSMIC_RAY' in available_flags:
        filtered_data = filtered_data[
            ~((filtered_data[flag]) & (filtered_data['COSMIC_RAY']))
        ]
    else:
        filtered_data = filtered_data[~filtered_data[flag]]

error_columns = [col for col in data.columns if 'psfMagError' in col]
filtered_data = filtered_data[
    (filtered_data[error_columns] <= 0.2).all(axis=1)
]

original_count = data.shape[0]
filtered_count = filtered_data.shape[0]
excluded_count = original_count - filtered_count

print(f"Original dataset size: {original_count}")
print(f"Filtered dataset size: {filtered_count}")
print(f"Number of rows excluded: {excluded_count}")
print(f"Percentage of data retained: {(filtered_count / original_count) * 100:.2f}%")
# Out:
# Original dataset size: 5000
# Filtered dataset size: 5000
# Number of rows excluded: 0
# Percentage of data retained: 100.00%

# %%
print(data.columns.tolist())
# Out:
# ['objID', 'skyVersion', 'run', 'rerun', 'camcol', 'field', 'obj', 'mode', 'nChild', 'type', 'clean', 'probPSF', 'insideMask', 'flags', 'rowc', 'rowcErr', 'colc', 'colcErr', 'rowv', 'rowvErr', 'colv', 'colvErr', 'rowc_u', 'rowc_g', 'rowc_r', 'rowc_i', 'rowc_z', 'rowcErr_u', 'rowcErr_g', 'rowcErr_r', 'rowcErr_i', 'rowcErr_z', 'colc_u', 'colc_g', 'colc_r', 'colc_i', 'colc_z', 'colcErr_u', 'colcErr_g', 'colcErr_r', 'colcErr_i', 'colcErr_z', 'sky_u', 'sky_g', 'sky_r', 'sky_i', 'sky_z', 'skyIvar_u', 'skyIvar_g', 'skyIvar_r', 'skyIvar_i', 'skyIvar_z', 'psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z', 'psfMagErr_u', 'psfMagErr_g', 'psfMagErr_r', 'psfMagErr_i', 'psfMagErr_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i', 'fiberMag_z', 'fiberMagErr_u', 'fiberMagErr_g', 'fiberMagErr_r', 'fiberMagErr_i', 'fiberMagErr_z', 'fiber2Mag_u', 'fiber2Mag_g', 'fiber2Mag_r', 'fiber2Mag_i', 'fiber2Mag_z', 'fiber2MagErr_u', 'fiber2MagErr_g', 'fiber2MagErr_r', 'fiber2MagErr_i', 'fiber2MagErr_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i', 'petroMag_z', 'petroMagErr_u', 'petroMagErr_g', 'petroMagErr_r', 'petroMagErr_i', 'petroMagErr_z', 'psfFlux_u', 'psfFlux_g', 'psfFlux_r', 'psfFlux_i', 'psfFlux_z', 'psfFluxIvar_u', 'psfFluxIvar_g', 'psfFluxIvar_r', 'psfFluxIvar_i', 'psfFluxIvar_z', 'fiberFlux_u', 'fiberFlux_g', 'fiberFlux_r', 'fiberFlux_i', 'fiberFlux_z', 'fiberFluxIvar_u', 'fiberFluxIvar_g', 'fiberFluxIvar_r', 'fiberFluxIvar_i', 'fiberFluxIvar_z', 'fiber2Flux_u', 'fiber2Flux_g', 'fiber2Flux_r', 'fiber2Flux_i', 'fiber2Flux_z', 'fiber2FluxIvar_u', 'fiber2FluxIvar_g', 'fiber2FluxIvar_r', 'fiber2FluxIvar_i', 'fiber2FluxIvar_z', 'petroFlux_u', 'petroFlux_g', 'petroFlux_r', 'petroFlux_i', 'petroFlux_z', 'petroFluxIvar_u', 'petroFluxIvar_g', 'petroFluxIvar_r', 'petroFluxIvar_i', 'petroFluxIvar_z', 'petroRad_u', 'petroRad_g', 'petroRad_r', 'petroRad_i', 'petroRad_z', 'petroRadErr_u', 'petroRadErr_g', 'petroRadErr_r', 'petroRadErr_i', 'petroRadErr_z', 'petroR50_u', 'petroR50_g', 'petroR50_r', 'petroR50_i', 'petroR50_z', 'petroR50Err_u', 'petroR50Err_g', 'petroR50Err_r', 'petroR50Err_i', 'petroR50Err_z', 'petroR90_u', 'petroR90_g', 'petroR90_r', 'petroR90_i', 'petroR90_z', 'petroR90Err_u', 'petroR90Err_g', 'petroR90Err_r', 'petroR90Err_i', 'petroR90Err_z', 'q_u', 'q_g', 'q_r', 'q_i', 'q_z', 'qErr_u', 'qErr_g', 'qErr_r', 'qErr_i', 'qErr_z', 'u_u', 'u_g', 'u_r', 'u_i', 'u_z', 'uErr_u', 'uErr_g', 'uErr_r', 'uErr_i', 'uErr_z', 'mE1_u', 'mE1_g', 'mE1_r', 'mE1_i', 'mE1_z', 'mE2_u', 'mE2_g', 'mE2_r', 'mE2_i', 'mE2_z', 'mE1E1Err_u', 'mE1E1Err_g', 'mE1E1Err_r', 'mE1E1Err_i', 'mE1E1Err_z', 'mE1E2Err_u', 'mE1E2Err_g', 'mE1E2Err_r', 'mE1E2Err_i', 'mE1E2Err_z', 'mE2E2Err_u', 'mE2E2Err_g', 'mE2E2Err_r', 'mE2E2Err_i', 'mE2E2Err_z', 'mRrCc_u', 'mRrCc_g', 'mRrCc_r', 'mRrCc_i', 'mRrCc_z', 'mRrCcErr_u', 'mRrCcErr_g', 'mRrCcErr_r', 'mRrCcErr_i', 'mRrCcErr_z', 'mCr4_u', 'mCr4_g', 'mCr4_r', 'mCr4_i', 'mCr4_z', 'mE1PSF_u', 'mE1PSF_g', 'mE1PSF_r', 'mE1PSF_i', 'mE1PSF_z', 'mE2PSF_u', 'mE2PSF_g', 'mE2PSF_r', 'mE2PSF_i', 'mE2PSF_z', 'mRrCcPSF_u', 'mRrCcPSF_g', 'mRrCcPSF_r', 'mRrCcPSF_i', 'mRrCcPSF_z', 'mCr4PSF_u', 'mCr4PSF_g', 'mCr4PSF_r', 'mCr4PSF_i', 'mCr4PSF_z', 'deVRad_u', 'deVRad_g', 'deVRad_r', 'deVRad_i', 'deVRad_z', 'deVRadErr_u', 'deVRadErr_g', 'deVRadErr_r', 'deVRadErr_i', 'deVRadErr_z', 'deVAB_u', 'deVAB_g', 'deVAB_r', 'deVAB_i', 'deVAB_z', 'deVABErr_u', 'deVABErr_g', 'deVABErr_r', 'deVABErr_i', 'deVABErr_z', 'deVPhi_u', 'deVPhi_g', 'deVPhi_r', 'deVPhi_i', 'deVPhi_z', 'deVMag_u', 'deVMag_g', 'deVMag_r', 'deVMag_i', 'deVMag_z', 'deVMagErr_u', 'deVMagErr_g', 'deVMagErr_r', 'deVMagErr_i', 'deVMagErr_z', 'deVFlux_u', 'deVFlux_g', 'deVFlux_r', 'deVFlux_i', 'deVFlux_z', 'deVFluxIvar_u', 'deVFluxIvar_g', 'deVFluxIvar_r', 'deVFluxIvar_i', 'deVFluxIvar_z', 'expRad_u', 'expRad_g', 'expRad_r', 'expRad_i', 'expRad_z', 'expRadErr_u', 'expRadErr_g', 'expRadErr_r', 'expRadErr_i', 'expRadErr_z', 'expAB_u', 'expAB_g', 'expAB_r', 'expAB_i', 'expAB_z', 'expABErr ...

# %%
error_columns = ['psfMagErr_u', 'psfMagErr_g', 'psfMagErr_r', 'psfMagErr_i', 'psfMagErr_z']


filtered_data = data[
    (data[error_columns] <= 0.5).all(axis=1)  # Retain rows where all errors are <= 0.5
]


original_count = data.shape[0]
filtered_count = filtered_data.shape[0]
excluded_count = original_count - filtered_count

print(f"Original dataset size: {original_count}")
print(f"Filtered dataset size: {filtered_count}")
print(f"Number of rows excluded: {excluded_count}")
print(f"Percentage of data retained: {(filtered_count / original_count) * 100:.2f}%")
# Out:
# Original dataset size: 5000
# Filtered dataset size: 2536
# Number of rows excluded: 2464
# Percentage of data retained: 50.72%

# %%
flags_to_check = ['EDGE', 'COSMIC_RAY', 'NOPROFILE']  # Replace with actual flag column names
flag_summary = {flag: data[flag].sum() for flag in flags_to_check if flag in data.columns}

error_columns = ['psfMagErr_u', 'psfMagErr_g', 'psfMagErr_r', 'psfMagErr_i', 'psfMagErr_z']
psf_error_summary = data[error_columns].describe()

original_count = data.shape[0]
filtered_count = filtered_data.shape[0]
retention_rate = (filtered_count / original_count) * 100

magnitude_columns = ['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z']
magnitude_summary = data[magnitude_columns].describe()


data['g-r'] = data['psfMag_g'] - data['psfMag_r']
data['r-i'] = data['psfMag_r'] - data['psfMag_i']
color_summary = data[['g-r', 'r-i']].describe()


print("Flag Summary:")
print(flag_summary)

print("\nPSF Error Summary:")
print(psf_error_summary)

print("\nRetention Rate:")
print(f"Original dataset size: {original_count}")
print(f"Filtered dataset size: {filtered_count}")
print(f"Percentage of data retained: {retention_rate:.2f}%")

print("\nMagnitude Summary:")
print(magnitude_summary)

print("\nColor Index Summary:")
print(color_summary)
# Out:
# Flag Summary:
# {}
#
# PSF Error Summary:
#        psfMagErr_u  psfMagErr_g  psfMagErr_r  psfMagErr_i  psfMagErr_z
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.457148     0.161675     0.088181     0.101236     0.207179
# std       0.790524     0.358999     0.106773     0.144122     0.212151
# min       0.009138     0.012363     0.009306     0.000692     0.011622
# 25%       0.178634     0.031258     0.022477     0.022469     0.039726
# 50%       0.461850     0.097652     0.063111     0.052595     0.134487
# 75%       0.636569     0.221687     0.137048     0.128597     0.339139
# max      51.533700    21.294840     3.436052     2.952048     5.264926
#
# Retention Rate:
# Original dataset size: 5000
# Filtered dataset size: 2536
# Percentage of data retained: 50.72%
#
# Magnitude Summary:
#           psfMag_u     psfMag_g     psfMag_r     psfMag_i     psfMag_z
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     23.004704    21.866774    20.894628    20.427817    20.074665
# std       1.880086     2.130366     1.965942     2.050669     2.028237
# min      15.000970    14.430290    14.041710    13.452560    12.763660
# 25%      22.240040    20.767428    19.904185    19.300722    18.896560
# 50%      23.454385    22.424955    21.483505    20.861260    20.486550
# 75%      24.260270    23.394445    22.425155    21.929537    21.636313
# max      26.295780    26.039330    25.415470    25.173790    24.218080
#
# Color Index Summary:
#                g-r          r-i
# count  5000.000000  5000.000000
# mean      0.972146     0.466811
# std       0.554319     0.556032
# min      -0.987980    -3.670140
# 25%       0.489640     0.139473
# 50%       0.965725     0.341135
# 75%       1.386808     0.794305
# max       5.154850     2.930830

# %% [markdown]
# # II. Workflow

# %%
ra_range = (data['ra'].min(), data['ra'].max())
dec_range = (data['dec'].min(), data['dec'].max())

magnitude_columns = ['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z']
magnitude_summary = data[magnitude_columns].describe()

error_columns = ['psfMagErr_u', 'psfMagErr_g', 'psfMagErr_r', 'psfMagErr_i', 'psfMagErr_z']
psf_error_summary = data[error_columns].describe()

flag_columns = ['EDGE', 'COSMIC_RAY', 'NOPROFILE']
flag_counts = {flag: data[flag].sum() for flag in flag_columns if flag in data.columns}

total_rows = data.shape[0]
total_columns = data.shape[1]
critical_columns_present = all(col in data.columns for col in ['ra', 'dec', *magnitude_columns])


print(f"RA Range: {ra_range}")
print(f"Dec Range: {dec_range}")
print("\nPhotometric Magnitudes Summary:")
print(magnitude_summary)

print("\nPSF Magnitude Errors Summary:")
print(psf_error_summary)

print("\nQuality Flags Exclusion Counts:")
print(flag_counts)

print(f"\nTotal Rows: {total_rows}")
print(f"Total Columns: {total_columns}")
print(f"Critical Columns Present: {critical_columns_present}")
# Out:
# RA Range: (np.float64(180.0005002), np.float64(180.9999685))
# Dec Range: (np.float64(-0.499868247), np.float64(0.420111521))
#
# Photometric Magnitudes Summary:
#           psfMag_u     psfMag_g     psfMag_r     psfMag_i     psfMag_z
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     23.004704    21.866774    20.894628    20.427817    20.074665
# std       1.880086     2.130366     1.965942     2.050669     2.028237
# min      15.000970    14.430290    14.041710    13.452560    12.763660
# 25%      22.240040    20.767428    19.904185    19.300722    18.896560
# 50%      23.454385    22.424955    21.483505    20.861260    20.486550
# 75%      24.260270    23.394445    22.425155    21.929537    21.636313
# max      26.295780    26.039330    25.415470    25.173790    24.218080
#
# PSF Magnitude Errors Summary:
#        psfMagErr_u  psfMagErr_g  psfMagErr_r  psfMagErr_i  psfMagErr_z
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.457148     0.161675     0.088181     0.101236     0.207179
# std       0.790524     0.358999     0.106773     0.144122     0.212151
# min       0.009138     0.012363     0.009306     0.000692     0.011622
# 25%       0.178634     0.031258     0.022477     0.022469     0.039726
# 50%       0.461850     0.097652     0.063111     0.052595     0.134487
# 75%       0.636569     0.221687     0.137048     0.128597     0.339139
# max      51.533700    21.294840     3.436052     2.952048     5.264926
#
# Quality Flags Exclusion Counts:
# {}
#
# Total Rows: 5000
# Total Columns: 511
# Critical Columns Present: True

# %% [markdown]
# # Results
# ## Data Preparation and Descriptive Statistics

# %%
import pandas as pd

# RA and Dec ranges
ra_min, ra_max = data['ra'].min(), data['ra'].max()
dec_min, dec_max = data['dec'].min(), data['dec'].max()

# Photometric Magnitudes
photometric_bands = ['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z']
photometric_stats = data[photometric_bands].describe()

# Dataset Retention
original_count = 5000  
filtered_count = data.shape[0]
retention_rate = (filtered_count / original_count) * 100

# Validation Metrics - PSF Errors
psf_error_columns = ['psfMagErr_u', 'psfMagErr_g', 'psfMagErr_r', 'psfMagErr_i', 'psfMagErr_z']
psf_error_stats = data[psf_error_columns].describe()

print("RA Range:", (ra_min, ra_max))
print("Dec Range:", (dec_min, dec_max))
print("\nPhotometric Magnitude Statistics:")
print(photometric_stats)
print(f"\nDataset Retention: {filtered_count}/{original_count} ({retention_rate:.2f}%)")
print("\nPSF Magnitude Error Statistics:")
print(psf_error_stats)
# Out:
# RA Range: (np.float64(180.0005002), np.float64(180.9999685))
# Dec Range: (np.float64(-0.499868247), np.float64(0.420111521))
#
# Photometric Magnitude Statistics:
#           psfMag_u     psfMag_g     psfMag_r     psfMag_i     psfMag_z
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     23.004704    21.866774    20.894628    20.427817    20.074665
# std       1.880086     2.130366     1.965942     2.050669     2.028237
# min      15.000970    14.430290    14.041710    13.452560    12.763660
# 25%      22.240040    20.767428    19.904185    19.300722    18.896560
# 50%      23.454385    22.424955    21.483505    20.861260    20.486550
# 75%      24.260270    23.394445    22.425155    21.929537    21.636313
# max      26.295780    26.039330    25.415470    25.173790    24.218080
#
# Dataset Retention: 5000/5000 (100.00%)
#
# PSF Magnitude Error Statistics:
#        psfMagErr_u  psfMagErr_g  psfMagErr_r  psfMagErr_i  psfMagErr_z
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.457148     0.161675     0.088181     0.101236     0.207179
# std       0.790524     0.358999     0.106773     0.144122     0.212151
# min       0.009138     0.012363     0.009306     0.000692     0.011622
# 25%       0.178634     0.031258     0.022477     0.022469     0.039726
# 50%       0.461850     0.097652     0.063111     0.052595     0.134487
# 75%       0.636569     0.221687     0.137048     0.128597     0.339139
# max      51.533700    21.294840     3.436052     2.952048     5.264926

# %% [markdown]
# # EDA

# %% [markdown]
# # Color-Magnitude Diagrams (CMDs)

# %%
import matplotlib.pyplot as plt

# %%
data['g-r'] = data['psfMag_g'] - data['psfMag_r']

# Plot the CMD: (g-r) vs. r magnitude
plt.figure(figsize=(8, 6))
plt.scatter(data['g-r'], data['psfMag_r'], s=1, alpha=0.5, color='blue')
plt.gca().invert_yaxis()  # Invert y-axis for magnitude (brighter stars lower)
plt.title('Color-Magnitude Diagram (g-r vs. r)')
plt.xlabel('g-r (Color Index)')
plt.ylabel('r (Magnitude)')
plt.grid()
plt.show()

# %%
print(data.columns)
# Out:
# Index(['objID', 'skyVersion', 'run', 'rerun', 'camcol', 'field', 'obj', 'mode',
#        'nChild', 'type',
#        ...
#        'nMgyPerCount_g', 'nMgyPerCount_r', 'nMgyPerCount_i', 'nMgyPerCount_z',
#        'TAI_u', 'TAI_g', 'TAI_r', 'TAI_i', 'TAI_z', 'g-r'],
#       dtype='object', length=510)

# %%
# Calculate the r-i color index
if 'psfMag_r' in data.columns and 'psfMag_i' in data.columns:
    data['r-i'] = data['psfMag_r'] - data['psfMag_i']
else:
    print("psfMag_r or psfMag_i column is missing!")

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data['r-i'], data['psfMag_i'], s=1, alpha=0.5, color='green')
plt.gca().invert_yaxis()  # Invert y-axis for magnitude
plt.title('Color-Magnitude Diagram (r-i vs. i)')
plt.xlabel('r-i (Color Index)')
plt.ylabel('i (Magnitude)')
plt.grid()
plt.show()

# %%
data['u-g'] = data['psfMag_u'] - data['psfMag_g']
data['i-z'] = data['psfMag_i'] - data['psfMag_z']


plt.figure(figsize=(8, 6))
plt.scatter(data['u-g'], data['psfMag_g'], s=1, alpha=0.5, color='blue')
plt.gca().invert_yaxis()  # Invert y-axis for magnitude
plt.title('Color-Magnitude Diagram (u-g vs. g)')
plt.xlabel('u-g (Color Index)')
plt.ylabel('g (Magnitude)')
plt.grid()
plt.show()


plt.figure(figsize=(8, 6))
plt.scatter(data['i-z'], data['psfMag_z'], s=1, alpha=0.5, color='red')
plt.gca().invert_yaxis()  # Invert y-axis for magnitude
plt.title('Color-Magnitude Diagram (i-z vs. z)')
plt.xlabel('i-z (Color Index)')
plt.ylabel('z (Magnitude)')
plt.grid()
plt.show()

# %% [markdown]
# # Histograms of Magnitudes and Color Indices

# %%
import matplotlib.pyplot as plt


magnitude_columns = ['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z']


histograms = {}
for mag in magnitude_columns:
    plt.figure(figsize=(8, 6))
    plt.hist(data[mag], bins=50, alpha=0.7, color='blue', edgecolor='black')
    plt.title(f'Distribution of {mag}')
    plt.xlabel('Magnitude')
    plt.ylabel('Frequency')
    plt.grid()
    plt.show()


    histograms[mag] = {
        "mean": data[mag].mean(),
        "median": data[mag].median(),
        "std_dev": data[mag].std(),
        "min": data[mag].min(),
        "max": data[mag].max()
    }

histograms
# Out:
# {'psfMag_u': {'mean': np.float64(23.004703846),
#   'median': np.float64(23.454385000000002),
#   'std_dev': np.float64(1.8800855539138732),
#   'min': np.float64(15.00097),
#   'max': np.float64(26.29578)},
#  'psfMag_g': {'mean': np.float64(21.866774067999998),
#   'median': np.float64(22.424955),
#   'std_dev': np.float64(2.130365671847096),
#   'min': np.float64(14.43029),
#   'max': np.float64(26.03933)},
#  'psfMag_r': {'mean': np.float64(20.89462842),
#   'median': np.float64(21.483505),
#   'std_dev': np.float64(1.965942407921401),
#   'min': np.float64(14.04171),
#   'max': np.float64(25.41547)},
#  'psfMag_i': {'mean': np.float64(20.427817298),
#   'median': np.float64(20.86126),
#   'std_dev': np.float64(2.0506693133805283),
#   'min': np.float64(13.45256),
#   'max': np.float64(25.17379)},
#  'psfMag_z': {'mean': np.float64(20.07466505),
#   'median': np.float64(20.48655),
#   'std_dev': np.float64(2.0282365293043902),
#   'min': np.float64(12.76366),
#   'max': np.float64(24.21808)}}

# %% [markdown]
# #  Distribution of Color Indices

# %%
print(data[['g-r', 'r-i']].describe())


# g-r
plt.figure(figsize=(8, 6))
plt.hist(data['g-r'], bins=50, alpha=0.7, color='blue', edgecolor='black')
plt.title('Histogram of g-r Color Index')
plt.xlabel('g-r')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# r-i
plt.figure(figsize=(8, 6))
plt.hist(data['r-i'], bins=50, alpha=0.7, color='green', edgecolor='black')
plt.title('Histogram of r-i Color Index')
plt.xlabel('r-i')
plt.ylabel('Frequency')
plt.grid()
plt.show()
# Out:
#                g-r          r-i
# count  5000.000000  5000.000000
# mean      0.972146     0.466811
# std       0.554319     0.556032
# min      -0.987980    -3.670140
# 25%       0.489640     0.139473
# 50%       0.965725     0.341135
# 75%       1.386808     0.794305
# max       5.154850     2.930830
